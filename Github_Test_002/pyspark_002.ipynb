# %%
from pyspark.sql  import functions as F
from pyspark.sql  import types as T
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("employee").getOrCreate()
data = [(1,'Rahul'),
        (2,'Ujjawal'),
        ]
columns = ['id','name']        
df1 = spark.createDataFrame(data,columns)
df1.show()

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("department").getOrCreate()
data = [

    ('IT',50000),
    ('HR',8500)]
columns = ['department','salary']
df2 = spark.createDataFrame(data,columns)
df2.show()

# %%
from  pyspark.sql import SparkSession
spark = SparkSession.builder.appName("order").getOrCreate()
data = [(1,'MOBILE'),
        (2,'TV'),
        (3,'BOTTEL'),
        (4,'ICE'),
        (5,'MILK') ]

columns = ['id','order_name']
df3 = spark.createDataFrame(data,columns)
df3.show()

# %%
from pyspark.sql import SparkSession
spark  = SparkSession.builde.appName("rahul_ujjawal").getOrCreate()
data = []
